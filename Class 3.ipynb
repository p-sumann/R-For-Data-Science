# %%
x <- c(1:30)
y <- x^3

# %%
plot(x,y)
# Out:
# plot without title

# %%
plot(x)
# Out:
# plot without title

# %%
hist(x)
# Out:
# Plot with title "Histogram of x"

# %%
hist(y)
# Out:
# Plot with title "Histogram of y"

# %%
ggplot2(x,aes(x)+geom_point())
# Out:
# Error in ggplot2(x, aes(x) + geom_point()): could not find function "ggplot2"
# Traceback:

# %%
# store the current directory
initial.dir <- getwd()
initial.dir
# Out:
# [1] "c:/Users/SumanPaudel/Desktop/R For Data Science"

# %%
# change to the new driectory
setwd('c:/Users/SumanPaudel/Desktop/R For Data Science')

# %%
# load thencessary libraries
library(magrittr)

# %%
# set the output file (bypass R and R Studio)

sink("session3.txt")

# %%
# load the dataset from test folder
iris <- iris

# %%
plot(iris$Sepal.Length,iris$Petal.Length)
# Out:
# plot without title
